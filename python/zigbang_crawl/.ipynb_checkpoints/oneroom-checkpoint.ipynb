# %%
import requests
import copy
import csv
import time
import json
import uuid
import pprint
import asyncio
from typing import List
from urllib import parse
from urllib.parse import quote
import inspect
import datetime

# %%
class magic_fstring_function:
    def __init__(self, payload):
        self.payload = payload
        self.cached = None
    def __str__(self):
        if self.cached is None:
            vars = inspect.currentframe().f_back.f_globals.copy()
            vars.update(inspect.currentframe().f_back.f_locals)
            self.cached = self.payload.format(**vars)
        return self.cached

# %%
uuid = str(uuid.uuid4())
item_list_api = "https://apis.zigbang.com/v2/items"
describe_list_api = item_list_api + '/list'
item_describe_api = "https://apis.zigbang.com/v3/items?item_ids={item_id}&detail=true"
item_view_url = "https://zigbang.com/home/oneroom/items/{item_id}"

referer = "https://zigbang.com/home/oneroom/subways/414/items"
        
headers = {
    'Host':'apis.zigbang.com',
    'Connection':'keep-alive',
    'Pragma':'no-cache',
    'Cache-Control':'no-cache',
    'Accept':'application/json, text/plain, */*',
    'Origin':'https://zigbang.com',
    'User-Agent':'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Mobile Safari/537.36',
    'DNT':'1',
    'Sec-Fetch-Site':'same-site',
    'Sec-Fetch-Mode':'cors',
    'Referer':'https://zigbang.com/home/oneroom/subways/414/items',
    'Accept-Encoding':'gzip, deflate, br',
    'Accept-Language':'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
}

items = {}

# %%
def export_items(items):
    fieldnames = [
        'address1',
        'address2',
        'address3',
        'agent_address1',
        'agent_email',
        'agent_lat',
        'agent_lng',
        'agent_mobile',
        'agent_name',
        'agent_phone',
        'building_type',
        'deposit',
        'description',
        'elevator',
        'floor',
        'floor_all',
        'images',
        'local1',
        'local2',
        'local3',
        'manage_cost',
        'manage_cost_inc',
        'movein_date',
        'near_subways',
        'options',
        'parking',
        'pets_text',
        'random_location',
        'room_direction_text',
        'room_type',
        'sales_type',
        'service_type',
        'size',
        'size_m2',
        'title',
        'updated_at2',
        'user_intro',
        'user_name',
        'url'
    ]
    
    filtered_item = [] 

    for item in items:
        item = item['item']
        item_id = item['id']
        url = magic_fstring_function(item_view_url)
        item['url'] = str(url)
        new_item = {}
        for fieldname in fieldnames:
            new_item[fieldname] = item[fieldname]
        filtered_item.append(new_item)
    return filtered_item

# %%
def describe_room_list(items):
    item_ids = items
    max_idx = int(len(item_ids) / 30)
    if len(item_ids) % 30 != 0:
        max_idx += 1
    
    items = []
    headers['Accept'] = 'application/json'
    headers['Referer'] = 'https://zigbang.com/home/oneroom/subways/37/items'
    
    for i in range(max_idx):
        start_idx = i * 30
        end_idx = min((i+1)*30, len(item_ids))
        sub_ids = item_ids[start_idx:end_idx-1]
        item_id = str(sub_ids).replace(' ', '').replace('\'','')
        api = magic_fstring_function(item_describe_api)
        g = api
        resp = requests.get(
            url=str(api),
            headers=headers,
            timeout=5,
        )
        resp.encoding = 'utf-8'
        result = resp.json()
        resp.close()
        items += result['items']
        time.sleep(1)
        
    return items

# %%
def get_room_list(
    items,
    domain: str = "zigbang",
    floor_in: str = "ground",
    geohash: str = "wyd",
    rent_gteq: int = 0,
    service_type_eq: str = "원룸",
):
    resp = requests.get(
        url=item_list_api,
        params={
            "domain": domain,
            "floor_in": floor_in,
            "geohash": geohash,
            "rent_gteq": rent_gteq,
            "service_type_eq": service_type_eq,
        },
        headers=headers,
        timeout=5,
    )
    new_items = json.loads(resp.content.decode('utf-8'))
    resp.close()

    for section in new_items['sections']:
        for item in section['item_ids']:
            items.append(str(item))

    return items

# %%
items = []

# %%
geos_seoul = [
    'wydm',
    'wydq4',
    'wydq5',
    'wydjx',
    'wydjr',
    'wydjq'
] 

for geo in geos_seoul:
    items = get_room_list(items, geohash=geo)
    time.sleep(1)

# %%
len(items)
# Out:
# 26273

# %%
import random

random_items = random.sample(items, 5000)

# %%
result = describe_room_list(random_items)
len(result)
# Out:
# 4833

# %%
pp = pprint.PrettyPrinter(indent=2)
pp.pprint(result[0]['item'])
# Out:
# { '_floor': '5층',
#   'address1': '서울시 강동구 성내동',
#   'address2': '199-21',
#   'address3': None,
#   'agent_address1': '서울특별시 강동구 성안로3길 86 1층(성내동)',
#   'agent_comment': '',
#   'agent_email': '0130cyh@hanmail.net',
#   'agent_lat': 37.52745325257799,
#   'agent_lng': 127.125360720025,
#   'agent_local1': '서울시',
#   'agent_local2': '강동구',
#   'agent_mobile': '010-4153-8724',
#   'agent_name': '보성부동산공인중개사사무소(조유희)',
#   'agent_no': 0,
#   'agent_phone': '02-4824-889 ',
#   'bjd_code': '',
#   'bonbun_code': '199',
#   'bubun_code': '21',
#   'building': None,
#   'building_type': '다세대건물',
#   'contract': '서울특별시',
#   'deposit': 200,
#   'description': '- 강동역 도보 4분거리 역세권 오픈형원룸\r\n'
#                  '\r\n'
#                  '- 주변에 대학병원, 마트등이 도보 5분내에 있어 \r\n'
#                  '   편리한 생활권\r\n'
#                  '\r\n'
#                  '- 큰도로와 인접해 있어 귀가길 안심\r\n'
#                  '\r\n'
#                  '- 위 사진은 다른층 공실사진으로 참고하세요~\r\n'
#                  '\r\n'
#                  '- 전용 넓고 깨끗하고 관리 잘 되어 있습니다~\r\n'
#                  '\r\n'
#                  '- 보증금이 정말 저렴하고 살기 좋은 원룸이라 \r\n'
#                  '   서두르세요^^~~\n'
#                  '21.10.19에 직방에 등록된 매물입니다.',
#   'description_og': '- 강동역 도보 4분거리 역세권 오픈형원룸\r\n'
#                     '\r\n'
#                     '- 주변에 대학병원, 마트등이 도보 5분내에 있어 \r\n'
#                     '   편리한 생활권\r\n'
#                     '\r\n'
#                     '- 큰도로와 인접해 있어 귀가길 안심\r\n'
#                     '\r\n'
#                     '- 위 사진은 다른층 공실사진으로 참고하세요~\r\n'
#                     '\r\n'
#                     '- 전용 넓고 깨끗하고 관리 잘 되어 있습니다~\r\n'
#                     '\r\n'
#                     '- 보증금이 정말 저렴하고 살기 좋은 원룸이라 \r\n'
#                     '   서두르세요^^~~\n'
#                     '21.10.19에 직방에 등록된 매물입니다.',
#   'elevator': '있음',
#   'floor': '5층',
#   'floor_all': '8층',
#   'id': 29038239,
#   'images': [ { 'count': 1,
#                 'index': 0,
#                 'url': 'https://ic.zigbang.com/ic/items/29038239/1.jpg'},
#               { 'count': 2,
#                 'index': 1,
#                 'url': 'https://ic.zigbang.com/ic/items/29038239/2.jpg'},
#               { 'count': 3,
#                 'index': 2,
#                 'url': 'https://ic.zigbang.com/ic/items/29038239/3.jpg'},
#               { 'count': 4,
#                 'index': 3,
#                 'url': 'https://ic.zigbang.com/ic/items/29038239/4.jpg'},
#               { 'count': 5,
#                 'index': 4,
#                 'url': 'https://ic.zigbang.com/ic/items/29038239/5.jpg'},
#               { 'count': 6,
#                 'index': 5,
#                 'url': 'https://ic.zigbang.com/ic/items/29038239/6.jpg'},
#               { 'count': 7,
#                 'index': 6,
#                 'url': 'https://ic.zigbang.com/ic/items/29038239/7.jpg'}],
#   'images_thumbnail': '/items/29038239/1.jpg',
#   'is_deposit_only': False,
#   'is_direct': False,
#   'is_homepage': True,
#   'is_owner': False,
#   'is_premium': True,
#   'is_premium2': False,
#   'is_realestate': True,
#   'is_room': False,
#   'is_status_close': False,
#   'is_status_open': True,
#   'is_type_room': False,
#   'is_zzim': False,
#   'loan_text': '확인필요',
#   'local1': '서울시',
#   'local2': '강동구',
#   'local3': '성내동',
#   'manage_cost': '6만원',
#   'manage_cost_inc': '-',
#   'movein_date': '2021. 10. 26 이후',
#   'near_subways': '강동역(5호선), 길동역(5호선), 둔촌동역(5호선)',
#   'options': '에어컨,냉장고,세탁기,가스레인지',
#   'original_user_phone': '010-4153-8724',
#   'parking': '불가능',
#   'pets_text': '확인필요',
#   'pnu': '1174010800101990021',
#   'premium_items': [],
#   'profile_url': 'http://ic.zigbang.com/vp/profile/3930064/50249e0a059ceb4f5aadac888d691b71e8d0bdcd.jpg',
#   'random_location': '37.53433152042627,127.13406803793139',
#   'read_updated_at': '2001-01-01',
#   'rent': 68,
#   'room_direction_text': '동향',
#   'room_gubun_code': '01',
#   'room_type': '오픈형 원룸',
#   'room_type_code': '01',
#   'sales_type': '월세',
#   'secret_memo': None,
#   'service_type': '원룸',
#   'size': 9.2,
#   'size_contract': 0,
#   'size_m2': 30.25,
#   'size_m2_contract': '-',
#   'status': '광고중',
#   'title': '강동역세권 보증금 저렴하고 깨끗한 풀옵션원룸',
#   'updated_at': '22일 전',
#   'updated_at2': '2021-10-19',
#   'user_email': '0130cyh@hanmail.net',
#   'user_has_no_penalty': True,
#   'user_has_penalty': False,
#   'user_intro': '저희 보성부동산은 아파트,주택,오피스텔,상가 등 다양한 매물\r\n'
#                 '고객님이 원하시는 매물 찾으실때까지 최선을 다하는 부동산입니다.',
#   'user_mobile': '0504-3128-4868',
#   'user_name': '대표공인중개사 조유희',
#   'user_no': 3930064,
#   'user_phone': '0504-3128-4868',
#   'view_count': '132'}

# %%
filtered_result = export_items(result)
len(filtered_result)
# Out:
# 4833

# %%
def get_string_image(item):
    image = ''
    
    for list in item:
        image += list['url'] + '?w=400&h=300&q=70&a=1,'
        
    return image[:-1]

# %%
def get_full_address(item):
    addr = item['address1']
    addr += ' '
    addr += item['address2'] or ''
    addr += ' '
    addr += item['address3'] or ''
    return addr

# %%
def get_location_lat(item):
    locationList = item['random_location'].split(',')

    lat = locationList[0][0:13]
    
    return lat

def get_location_lng(item):
    locationList = item['random_location'].split(',')

    lng = locationList[1][0:14]
    
    return lng

# %%
def get_agent_lat(item):
    agent_lat = str(item['agent_lat'])[0:13]
    
    return agent_lat

def get_agent_lng(item):
    agent_lng = str(item['agent_lng'])[0:14]
    
    return agent_lng

# %%
for item in filtered_result:
    item['address'] = get_full_address(item)
    item['lat'] = get_location_lat(item)
    item['lng'] = get_location_lng(item)
    item['image'] = get_string_image(item['images'])
    item['agent_lat'] = get_agent_lat(item)
    item['agent_lng'] = get_agent_lng(item)

# %%
pp = pprint.PrettyPrinter(indent=2)
pp.pprint(filtered_result[0])
# Out:
# { 'address': '서울시 강동구 성내동 199-21 ',
#   'address1': '서울시 강동구 성내동',
#   'address2': '199-21',
#   'address3': None,
#   'agent_address1': '서울특별시 강동구 성안로3길 86 1층(성내동)',
#   'agent_email': '0130cyh@hanmail.net',
#   'agent_lat': '37.5274532525',
#   'agent_lng': '127.1253607200',
#   'agent_mobile': '010-4153-8724',
#   'agent_name': '보성부동산공인중개사사무소(조유희)',
#   'agent_phone': '02-4824-889 ',
#   'building_type': '다세대건물',
#   'deposit': 200,
#   'description': '- 강동역 도보 4분거리 역세권 오픈형원룸\r\n'
#                  '\r\n'
#                  '- 주변에 대학병원, 마트등이 도보 5분내에 있어 \r\n'
#                  '   편리한 생활권\r\n'
#                  '\r\n'
#                  '- 큰도로와 인접해 있어 귀가길 안심\r\n'
#                  '\r\n'
#                  '- 위 사진은 다른층 공실사진으로 참고하세요~\r\n'
#                  '\r\n'
#                  '- 전용 넓고 깨끗하고 관리 잘 되어 있습니다~\r\n'
#                  '\r\n'
#                  '- 보증금이 정말 저렴하고 살기 좋은 원룸이라 \r\n'
#                  '   서두르세요^^~~\n'
#                  '21.10.19에 직방에 등록된 매물입니다.',
#   'elevator': '있음',
#   'floor': '5층',
#   'floor_all': '8층',
#   'image': 'https://ic.zigbang.com/ic/items/29038239/1.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29038239/2.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29038239/3.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29038239/4.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29038239/5.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29038239/6.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29038239/7.jpg?w=400&h=300&q=70&a=1',
#   'images': [ { 'count': 1,
#                 'index': 0,
#                 'url': 'https://ic.zigbang.com/ic/items/29038239/1.jpg'},
#               { 'count': 2,
#                 'index': 1,
#                 'url': 'https://ic.zigbang.com/ic/items/29038239/2.jpg'},
#               { 'count': 3,
#                 'index': 2,
#                 'url': 'https://ic.zigbang.com/ic/items/29038239/3.jpg'},
#               { 'count': 4,
#                 'index': 3,
#                 'url': 'https://ic.zigbang.com/ic/items/29038239/4.jpg'},
#               { 'count': 5,
#                 'index': 4,
#                 'url': 'https://ic.zigbang.com/ic/items/29038239/5.jpg'},
#               { 'count': 6,
#                 'index': 5,
#                 'url': 'https://ic.zigbang.com/ic/items/29038239/6.jpg'},
#               { 'count': 7,
#                 'index': 6,
#                 'url': 'https://ic.zigbang.com/ic/items/29038239/7.jpg'}],
#   'lat': '37.5343315204',
#   'lng': '127.1340680379',
#   'local1': '서울시',
#   'local2': '강동구',
#   'local3': '성내동',
#   'manage_cost': '6만원',
#   'manage_cost_inc': '-',
#   'movein_date': '2021. 10. 26 이후',
#   'near_subways': '강동역(5호선), 길동역(5호선), 둔촌동역(5호선)',
#   'options': '에어컨,냉장고,세탁기,가스레인지',
#   'parking': '불가능',
#   'pets_text': '확인필요',
#   'random_location': '37.53433152042627,127.13406803793139',
#   'room_direction_text': '동향',
#   'room_type': '오픈형 원룸',
#   'sales_type': '월세',
#   'service_type': '원룸',
#   'size': 9.2,
#   'size_m2': 30.25,
#   'title': '강동역세권 보증금 저렴하고 깨끗한 풀옵션원룸',
#   'updated_at2': '2021-10-19',
#   'url': 'https://zigbang.com/home/oneroom/items/29038239',
#   'user_intro': '저희 보성부동산은 아파트,주택,오피스텔,상가 등 다양한 매물\r\n'
#                 '고객님이 원하시는 매물 찾으실때까지 최선을 다하는 부동산입니다.',
#   'user_name': '대표공인중개사 조유희'}

# %%
with open('oneroom.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = [
        'address',
        'agent_address1',
        'agent_email',
        'agent_lat',
        'agent_lng',
        'agent_mobile',
        'agent_name',
        'agent_phone',
        'building_type',
        'deposit',
        'description',
        'elevator',
        'floor',
        'floor_all',
        'image',
        'lat',
        'lng',
        'local1',
        'local2',
        'local3',
        'manage_cost',
        'manage_cost_inc',
        'movein_date',
        'near_subways',
        'options',
        'parking',
        'pets_text',
        'room_direction_text',
        'room_type',
        'sales_type',
        'service_type',
        'size',
        'size_m2',
        'title',
        'updated_at2',
        'user_intro',
        'user_name',
        'url'
    ]
    writer = csv.DictWriter(csvfile, extrasaction='ignore', fieldnames=fieldnames)
    writer.writeheader()
    for item in filtered_result:
        writer.writerow(item)

# %%
import pymysql
import csv
conn = pymysql.connect(host='localhost', user='khweb', password='khWeb@123', db='mybang_db', charset='utf8mb4')
curs = conn.cursor()

sql = """insert into oneroom (address, agent_address, agent_email, agent_lat, agent_lng,
                            agent_mobile, agent_name, agent_phone, building_type, deposit, 
                            description, elevator, floor, floor_all, image,
                            lat, lng, local1, local2, local3,
                            manage_cost, manage_cost_inc, movein_date, near_subways, options,
                            parking, pets, room_direction, room_type, sales_type,
                            service_type, size, size_m2, title, updated_at,
                            user_intro, user_name, url)
                            values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,
                                    # %s,%s,%s,%s,%s,%s,%s,%s,%s,%s,
                                    # %s,%s,%s,%s,%s,%s,%s,%s,%s,%s,
                                    # %s,%s,%s,%s,%s,%s,%s,%s)"""

f = open('oneroom.csv', 'r', encoding='utf-8')
rd = csv.reader(f)

next(rd)

for line in rd:
    curs.execute(sql, (line[0], line[1], line[2], line[3], line[4], line[5], line[6], line[7], line[8], line[9], line[10], 
                       line[11], line[12], line[13], line[14], line[15], line[16], line[17], line[18], line[19], line[20], 
                       line[21], line[22], line[23], line[24], line[25], line[26], line[27], line[28], line[29], line[30], 
                       line[31], line[32], line[33], line[34], line[35], line[36], line[37]))
conn.commit()
conn.close()
f.close()
