# %%
import requests
import copy
import csv
import time
import json
import uuid
import pprint
import asyncio
from typing import List
from urllib import parse
from urllib.parse import quote
import inspect
import datetime

# %%
class magic_fstring_function:
    def __init__(self, payload):
        self.payload = payload
        self.cached = None
    def __str__(self):
        if self.cached is None:
            vars = inspect.currentframe().f_back.f_globals.copy()
            vars.update(inspect.currentframe().f_back.f_locals)
            self.cached = self.payload.format(**vars)
        return self.cached

# %%
uuid = str(uuid.uuid4())
item_list_api = "https://apis.zigbang.com/v2/items"
describe_list_api = item_list_api + '/list'
item_describe_api = "https://apis.zigbang.com/v3/items?item_ids={item_id}&detail=true"
item_view_url = "https://zigbang.com/home/villa/items/{item_id}"

referer = "https://zigbang.com/home/villa/subways/414/items"
        
headers = {
    'Host':'apis.zigbang.com',
    'Connection':'keep-alive',
    'Pragma':'no-cache',
    'Cache-Control':'no-cache',
    'Accept':'application/json, text/plain, */*',
    'Origin':'https://zigbang.com',
    'User-Agent':'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Mobile Safari/537.36',
    'DNT':'1',
    'Sec-Fetch-Site':'same-site',
    'Sec-Fetch-Mode':'cors',
    'Referer':'https://zigbang.com/home/villa/subways/414/items',
    'Accept-Encoding':'gzip, deflate, br',
    'Accept-Language':'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
}

items = {}

# %%
def export_items(items):
    fieldnames = [
        'address1',
        'address2',
        'address3',
        'agent_address1',
        'agent_email',
        'agent_lat',
        'agent_lng',
        'agent_mobile',
        'agent_name',
        'agent_phone',
        'building_type',
        'deposit',
        'description',
        'elevator',
        'floor',
        'floor_all',
        'images',
        'local1',
        'local2',
        'local3',
        'manage_cost',
        'manage_cost_inc',
        'movein_date',
        'near_subways',
        'options',
        'parking',
        'pets_text',
        'random_location',
        'room_direction_text',
        'room_type',
        'sales_type',
        'service_type',
        'size',
        'size_m2',
        'title',
        'updated_at2',
        'user_intro',
        'user_name',
        'url'
    ]
    
    filtered_item = [] 
    maximum_updated = datetime.timedelta(days=7)
    

    for item in items:
        item = item['item']

        item_updated = datetime.datetime.strptime(item['updated_at2'], '%Y-%m-%d')
        if maximum_updated < datetime.datetime.now() - item_updated:
            continue
        item_id = item['id']
        url = magic_fstring_function(item_view_url)
        item['url'] = str(url)
        new_item = {}
        for fieldname in fieldnames:
            new_item[fieldname] = item[fieldname]
        filtered_item.append(new_item)
    return filtered_item

# %%
def describe_room_list(items):
    item_ids = list(items.keys())
    max_idx = int(len(item_ids) / 30)
    if len(item_ids) % 30 != 0:
        max_idx += 1
    
    items = []
    headers['Accept'] = 'application/json'
    headers['Referer'] = 'https://zigbang.com/home/villa/subways/37/items'
    
    for i in range(max_idx):
        start_idx = i * 30
        end_idx = min((i+1)*30, len(item_ids))
        sub_ids = item_ids[start_idx:end_idx-1]
        item_id = str(sub_ids).replace(' ', '').replace('\'','')
        api = magic_fstring_function(item_describe_api)
        g = api
        resp = requests.get(
            url=str(api),
            headers=headers,
            timeout=5,
        )
        resp.encoding = 'utf-8'
        result = resp.json()
        resp.close()
        items += result['items']
        time.sleep(1)
        
    return items

# %%
def get_room_list(
    items,
    domain: str = "zigbang",
    floor_in: str = "ground",
    geohash: str = "wyd",
    rent_gteq: int = 0,
):
    resp = requests.get(
        url=item_list_api,
        params={
            "domain": domain,
            "floor_in": floor_in,
            "geohash": geohash,
            "rent_gteq": rent_gteq,
        },
        headers=headers,
        timeout=5,
    )
    new_items = json.loads(resp.content.decode('utf-8'))
    resp.close()

    for section in new_items['sections']:
        for item in section['item_ids']:
            items[str(item)] = {}

    return items

# %%
items = {}

# %%
geos_seoul = [
    'wydm',
    'wydq4',
    'wydq5',
    'wydjx',
    'wydjr',
    'wydjq',
] 

for geo in geos_seoul:
    items = get_room_list(items, geohash=geo)
    time.sleep(1)

# %%
from itertools import islice

len(items)

sliceItem = dict(islice(items.items(), 5000))

len(sliceItem)
# Out:
# 5000

# %%
print(sliceItem)
# Out:
# {'29272653': {}, '29154968': {}, '29109672': {}, '28998920': {}, '29206500': {}, '29169648': {}, '29005487': {}, '29249986': {}, '29232307': {}, '29157486': {}, '29037786': {}, '29052247': {}, '29069825': {}, '29246247': {}, '29212595': {}, '29277642': {}, '29011715': {}, '29277655': {}, '29253507': {}, '29123217': {}, '28718101': {}, '29267691': {}, '29263824': {}, '29180705': {}, '29211202': {}, '29134046': {}, '29276766': {}, '29242254': {}, '29293547': {}, '29257721': {}, '29288663': {}, '29053920': {}, '29094000': {}, '29231304': {}, '29296494': {}, '29240643': {}, '29286135': {}, '29225434': {}, '29229889': {}, '29250756': {}, '29221899': {}, '29142569': {}, '29018209': {}, '29269377': {}, '29174480': {}, '29196976': {}, '29262459': {}, '29221189': {}, '29296641': {}, '29209790': {}, '29288985': {}, '29012611': {}, '28898825': {}, '29181246': {}, '29159100': {}, '29221884': {}, '29136236': {}, '29012328': {}, '29221334': {}, '29227634': {}, '29234296': {}, '29275625': {}, '29180637': {}, '29230546': {}, '29263130': {}, '29172364': {}, '29091006': {}, '29286252': {}, '29126711': {}, '29294478': {}, '29253923': {}, '29007114': {}, '29230408': {}, '29026798': {}, '29240467': {}, '29253255': {}, '29109930': {}, '29277001': {}, '29208889': {}, '29277560': {}, '29229127': {}, '29263782': {}, '29295068': {}, '29166625': {}, '29257514': {}, '29224868': {}, '29227660': {}, '29247899': {}, '29224870': {}, '29035402': {}, '29093974': {}, '29289641': {}, '29250327': {}, '29242372': {}, '29128476': {}, '29243657': {}, '29293230': {}, '29275207': {}, '29219704': {}, '29267211': {}, '29198977': {}, '29295350': {}, '29270020': {}, '29116871': {}, '29228953': {}, '29227229': {}, '28961590': {}, '29284759': {}, '29075635': {}, '28956820': {}, '29251104': {}, '29178249': {}, '29282137': {}, '29199227': {}, '29291677': {}, '29233394': {}, '29208496': {}, '29240665': {}, '29134013': {}, '29199156': {}, '29281277': {}, '29242767': {}, '28914399': {}, '29014899': {}, '29207776': {}, '29224469': {}, '28978595': {}, '29291419': {}, '29233099': {}, '29233895': {}, '28846679': {}, '29269289': {}, '29295903': {}, '29288511': {}, '29235059': {}, '29285323': {}, '29293426': {}, '29012362': {}, '29252486': {}, '29247803': {}, '29268819': {}, '28956885': {}, '29294499': {}, '29029992': {}, '29290448': {}, '29287788': {}, '29251873': {}, '29154180': {}, '29116218': {}, '29195775': {}, '29208684': {}, '29162552': {}, '29236171': {}, '29295901': {}, '29153681': {}, '29219117': {}, '29026973': {}, '29270896': {}, '29236793': {}, '29254426': {}, '29225782': {}, '29204335': {}, '29117397': {}, '28962245': {}, '29053693': {}, '29056371': {}, '29285083': {}, '29206178': {}, '29181234': {}, '28910500': {}, '29200257': {}, '29251899': {}, '29156942': {}, '28868652': {}, '29270441': {}, '29062415': {}, '29154502': {}, '29191066': {}, '29251737': {}, '29092655': {}, '29250230': {}, '29285576': {}, '29225824': {}, '29191443': {}, '29227348': {}, '29189631': {}, '29285725': {}, '29160726': {}, '29104258': {}, '29021923': {}, '29250656': {}, '29197317': {}, '29278963': {}, '29103823': {}, '29256275': {}, '29278416': {}, '28801750': {}, '29270032': {}, '29280996': {}, '29220926': {}, '29101511': {}, '29224138': {}, '29294555': {}, '29281645': {}, '29264779': {}, '29288909': {}, '29182003': {}, '29081899': {}, '28939112': {}, '29294467': {}, '29277723': {}, '29222003': {}, '29257310': {}, '29276118': {}, '29083391': {}, '29139850': {}, '29281151': {}, '29232062': {}, '29182732': {}, '29048621': {}, '29270558': {}, '29132664': {}, '29283613': {}, '29261177': {}, '29296401': {}, '29259714': {}, '29259806': {}, '29290571': {}, '29278770': {}, '29250091': {}, '29236817': {}, '29286436': {}, '29251633': {}, '29212072': {}, '29275640': {}, '29256521': {}, '29293707': {}, '29232878': {}, '29216346': {}, '29234110': {}, '29216718': {}, '29286237': {}, '29233043': {}, '29208071': {}, '29272370': {}, '29266230': {}, '29218733': {}, '29042828': {}, '29271243': {}, '29107370': {}, ...

# %%
result = describe_room_list(sliceItem)

# %%
len(result)
# Out:
# 4833

# %%
pp = pprint.PrettyPrinter(indent=2)
pp.pprint(result[0]['item'])
# Out:
# { '_floor': '2층',
#   'address1': '서울시 중랑구 묵동',
#   'address2': '122-25',
#   'address3': None,
#   'agent_address1': '서울특별시 중랑구 동일로156길 16 1층 (묵동)',
#   'agent_comment': '',
#   'agent_email': 'tjdnf1160@naver.com',
#   'agent_lat': 37.60958480834961,
#   'agent_lng': 127.07839202880902,
#   'agent_local1': '서울시',
#   'agent_local2': '중랑구',
#   'agent_mobile': '010-3327-1160',
#   'agent_name': '서울부동산공인중개사사무소(김명자)',
#   'agent_no': 40810,
#   'agent_phone': '02-977-6330',
#   'bjd_code': '',
#   'bonbun_code': '122',
#   'bubun_code': '25',
#   'building': None,
#   'building_type': '-',
#   'contract': '서울특별시',
#   'deposit': 21000,
#   'description': '* 먹골역5분 신축4년 투룸빌라\r\n'
#                  '* 방2 거실 구조로 신혼집으로 추천드려요\r\n'
#                  '* 무인택배함,엘리베이터 있슴\r\n'
#                  '* 입주날짜 조정가능\r\n'
#                  '* 주차좋아요\r\n'
#                  '* 동네도 조용하고 깨끗해서 주거환경 아주좋아요 \r\n'
#                  '* 출퇴근하기 좋은 위치구요,주변상권 이용하기 편리해요\n'
#                  '21.11.01에 직방에 등록된 매물입니다.',
#   'description_og': '* 먹골역5분 신축4년 투룸빌라\r\n'
#                     '* 방2 거실 구조로 신혼집으로 추천드려요\r\n'
#                     '* 무인택배함,엘리베이터 있슴\r\n'
#                     '* 입주날짜 조정가능\r\n'
#                     '* 주차좋아요\r\n'
#                     '* 동네도 조용하고 깨끗해서 주거환경 아주좋아요 \r\n'
#                     '* 출퇴근하기 좋은 위치구요,주변상권 이용하기 편리해요\n'
#                     '21.11.01에 직방에 등록된 매물입니다.',
#   'elevator': '있음',
#   'floor': '2층',
#   'floor_all': '5층',
#   'id': 29272653,
#   'images': [ { 'count': 1,
#                 'index': 0,
#                 'url': 'https://ic.zigbang.com/ic/items/29272653/1.jpg'},
#               { 'count': 2,
#                 'index': 1,
#                 'url': 'https://ic.zigbang.com/ic/items/29272653/2.jpg'},
#               { 'count': 3,
#                 'index': 2,
#                 'url': 'https://ic.zigbang.com/ic/items/29272653/3.jpg'},
#               { 'count': 4,
#                 'index': 3,
#                 'url': 'https://ic.zigbang.com/ic/items/29272653/4.jpg'},
#               { 'count': 5,
#                 'index': 4,
#                 'url': 'https://ic.zigbang.com/ic/items/29272653/5.jpg'},
#               { 'count': 6,
#                 'index': 5,
#                 'url': 'https://ic.zigbang.com/ic/items/29272653/6.jpg'},
#               { 'count': 7,
#                 'index': 6,
#                 'url': 'https://ic.zigbang.com/ic/items/29272653/7.jpg'},
#               { 'count': 8,
#                 'index': 7,
#                 'url': 'https://ic.zigbang.com/ic/items/29272653/8.jpg'}],
#   'images_thumbnail': '/items/29272653/1.jpg',
#   'is_deposit_only': True,
#   'is_direct': False,
#   'is_homepage': True,
#   'is_owner': False,
#   'is_premium': True,
#   'is_premium2': True,
#   'is_realestate': True,
#   'is_room': False,
#   'is_status_close': False,
#   'is_status_open': True,
#   'is_type_room': False,
#   'is_zzim': False,
#   'loan_text': '확인필요',
#   'local1': '서울시',
#   'local2': '중랑구',
#   'local3': '묵동',
#   'manage_cost': '4만원',
#   'manage_cost_inc': '-',
#   'movein_date': '2022. 01. 05 이후',
#   'near_subways': '먹골역(7호선), 중화역(7호선), 태릉입구역(6호선,7호선)',
#   'options': '-',
#   'original_user_phone': '010-3771-2540',
#   'parking': '가능',
#   'pets_text': '확인필요',
#   'pnu': '1126010400101220025',
#   'premium_items': [],
#   'profile_url': 'http://ic.zigbang.com/vp/profile/407283.jpg',
#   'random_location': '37.61079622879896,127.08186247305541',
#   'read_updated_at': '2001-01-01',
#   'rent': 0,
#   'room_direction_text': '서향',
#   'room_gubun_code': '04',
#   'room_type': '투룸',
#   'room_type_code': '04',
#   'sales_type': '전세',
#   'secret_memo': None,
#   'service_type': '빌라',
#   'size': 13,
#   'size_contract': 14,
#   'size_m2': 42.98,
#   'size_m2_contract': 46.28,
#   'status': '광고중',
#   'title': '♦먹골역5분 신축4년 투룸빌라✔융자무,전세대출가능✔주차가능',
#   'updated_at': '17시간 전',
#   'updated_at2': '2021-11-01',
#   'user_email': 'tjdnf1160@naver.com',
#   'user_has_no_penalty': True,
#   'user_has_penalty': False,
#   'user_intro': '* 역세권의 특A급 매물을 다량 보유하고있는 서울부동산입니다\r\n'
#                 '* 안전한 부동산 거래를 원칙으로하며 계약부터 입주까지 책임지고 도와드리겠습니다\r\n'
#                 '* 서울부동산 오시는길▶중랑구 동일로 156길16 (먹골역4번출구 다비치안경점 뒤 편의점옆)\r\n'
#                 '\r\n',
#   'user_mobile': '0504-3128-7661',
#   'user_name': '중개보조원 정영태',
#   'user_no': 407283,
#   'user_phone': '0504-3128-7661',
#   'view_count': '49'}

# %%
filtered_result = export_items(result)

# %%
len(filtered_result)
# Out:
# 3114

# %%
def get_string_image(item):
    image = ''
    
    for list in item:
        image += list['url'] + '?w=400&h=300&q=70&a=1,'
        
    return image[:-1]

# %%
def get_full_address(item):
    addr = item['address1']
    addr += ' '
    addr += item['address2'] or ''
    addr += ' '
    addr += item['address3'] or ''
    return addr

# %%
def get_location_lat(item):
    locationList = item['random_location'].split(',')

    lat = locationList[0][0:9]
    
    return lat

def get_location_lng(item):
    locationList = item['random_location'].split(',')

    lng = locationList[1][0:10]
    
    return lng

# %%
def get_agent_lat(item):
    agent_lat = str(item['agent_lat'])[0:9]
    
    return agent_lat

def get_agent_lng(item):
    agent_lng = str(item['agent_lng'])[0:10]
    
    return agent_lng

# %%
geo_based_dict = {}

# %%
for item in filtered_result:
    full_addr = get_full_address(item)
    item['address'] = full_addr
    if full_addr not in geo_based_dict:
        geo_based_dict[full_addr] = []
    geo_based_dict[full_addr].append(item)

    item['lat'] = get_location_lat(item)
    item['lng'] = get_location_lng(item)
    item['image'] = get_string_image(item['images'])
    item['agent_lat'] = get_agent_lat(item)
    item['agent_lng'] = get_agent_lng(item)

# %%
first_key = next(iter(geo_based_dict))
pp.pprint(geo_based_dict[first_key][0])
# Out:
# { 'address': '서울시 중랑구 묵동 122-25 ',
#   'address1': '서울시 중랑구 묵동',
#   'address2': '122-25',
#   'address3': None,
#   'agent_address1': '서울특별시 중랑구 동일로156길 16 1층 (묵동)',
#   'agent_email': 'tjdnf1160@naver.com',
#   'agent_lat': '37.609584',
#   'agent_lng': '127.078392',
#   'agent_mobile': '010-3327-1160',
#   'agent_name': '서울부동산공인중개사사무소(김명자)',
#   'agent_phone': '02-977-6330',
#   'building_type': '-',
#   'deposit': 21000,
#   'description': '* 먹골역5분 신축4년 투룸빌라\r\n'
#                  '* 방2 거실 구조로 신혼집으로 추천드려요\r\n'
#                  '* 무인택배함,엘리베이터 있슴\r\n'
#                  '* 입주날짜 조정가능\r\n'
#                  '* 주차좋아요\r\n'
#                  '* 동네도 조용하고 깨끗해서 주거환경 아주좋아요 \r\n'
#                  '* 출퇴근하기 좋은 위치구요,주변상권 이용하기 편리해요\n'
#                  '21.11.01에 직방에 등록된 매물입니다.',
#   'elevator': '있음',
#   'floor': '2층',
#   'floor_all': '5층',
#   'image': 'https://ic.zigbang.com/ic/items/29272653/1.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29272653/2.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29272653/3.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29272653/4.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29272653/5.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29272653/6.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29272653/7.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29272653/8.jpg?w=400&h=300&q=70&a=1',
#   'images': [ { 'count': 1,
#                 'index': 0,
#                 'url': 'https://ic.zigbang.com/ic/items/29272653/1.jpg'},
#               { 'count': 2,
#                 'index': 1,
#                 'url': 'https://ic.zigbang.com/ic/items/29272653/2.jpg'},
#               { 'count': 3,
#                 'index': 2,
#                 'url': 'https://ic.zigbang.com/ic/items/29272653/3.jpg'},
#               { 'count': 4,
#                 'index': 3,
#                 'url': 'https://ic.zigbang.com/ic/items/29272653/4.jpg'},
#               { 'count': 5,
#                 'index': 4,
#                 'url': 'https://ic.zigbang.com/ic/items/29272653/5.jpg'},
#               { 'count': 6,
#                 'index': 5,
#                 'url': 'https://ic.zigbang.com/ic/items/29272653/6.jpg'},
#               { 'count': 7,
#                 'index': 6,
#                 'url': 'https://ic.zigbang.com/ic/items/29272653/7.jpg'},
#               { 'count': 8,
#                 'index': 7,
#                 'url': 'https://ic.zigbang.com/ic/items/29272653/8.jpg'}],
#   'lat': '37.610796',
#   'lng': '127.081862',
#   'local1': '서울시',
#   'local2': '중랑구',
#   'local3': '묵동',
#   'manage_cost': '4만원',
#   'manage_cost_inc': '-',
#   'movein_date': '2022. 01. 05 이후',
#   'near_subways': '먹골역(7호선), 중화역(7호선), 태릉입구역(6호선,7호선)',
#   'options': '-',
#   'parking': '가능',
#   'pets_text': '확인필요',
#   'random_location': '37.61079622879896,127.08186247305541',
#   'room_direction_text': '서향',
#   'room_type': '투룸',
#   'sales_type': '전세',
#   'service_type': '빌라',
#   'size': 13,
#   'size_m2': 42.98,
#   'title': '♦먹골역5분 신축4년 투룸빌라✔융자무,전세대출가능✔주차가능',
#   'updated_at2': '2021-11-01',
#   'url': 'https://zigbang.com/home/villa/items/29272653',
#   'user_intro': '* 역세권의 특A급 매물을 다량 보유하고있는 서울부동산입니다\r\n'
#                 '* 안전한 부동산 거래를 원칙으로하며 계약부터 입주까지 책임지고 도와드리겠습니다\r\n'
#                 '* 서울부동산 오시는길▶중랑구 동일로 156길16 (먹골역4번출구 다비치안경점 뒤 편의점옆)\r\n'
#                 '\r\n',
#   'user_name': '중개보조원 정영태'}

# %%
double_list = []
for addr in geo_based_dict.keys():
    double_list.append(geo_based_dict[addr][0])
double_list.sort(key=lambda x: x['size'], reverse=True)

# %%
with open('villa.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = [
        'address',
        'agent_address1',
        'agent_email',
        'agent_lat',
        'agent_lng',
        'agent_mobile',
        'agent_name',
        'agent_phone',
        'building_type',
        'deposit',
        'description',
        'elevator',
        'floor',
        'floor_all',
        'image',
        'lat',
        'lng',
        'local1',
        'local2',
        'local3',
        'manage_cost',
        'manage_cost_inc',
        'movein_date',
        'near_subways',
        'options',
        'parking',
        'pets_text',
        'room_direction_text',
        'room_type',
        'sales_type',
        'service_type',
        'size',
        'size_m2',
        'title',
        'updated_at2',
        'user_intro',
        'user_name',
        'url'
    ]
    writer = csv.DictWriter(csvfile, extrasaction='ignore', fieldnames=fieldnames)
    writer.writeheader()
    for item in double_list:
        writer.writerow(item)

# %%
# 크롤링한 csv 파일까지 커밋했으니까 이것만 run 하시면 됩니다!!!

import pymysql
import csv
conn = pymysql.connect(host='localhost', user='khweb', password='khweb@123', db='mybang_db', charset='utf8mb4')
curs = conn.cursor()

sql = """insert into villa (address, agent_address, agent_email, agent_lat, agent_lng,
                            agent_mobile, agent_name, agent_phone, building_type, deposit, 
                            description, elevator, floor, floor_all, image,
                            lat, lng, local1, local2, local3,
                            manage_cost, manage_cost_inc, movein_date, near_subways, options,
                            parking, pets, room_direction, room_type, sales_type,
                            service_type, size, size_m2, title, updated_at,
                            user_intro, user_name, url)
                            values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,
                                    # %s,%s,%s,%s,%s,%s,%s,%s,%s,%s,
                                    # %s,%s,%s,%s,%s,%s,%s,%s,%s,%s,
                                    # %s,%s,%s,%s,%s,%s,%s,%s)"""

f = open('villa.csv', 'r', encoding='utf-8')
rd = csv.reader(f)

next(rd)

for line in rd:
    curs.execute(sql, (line[0], line[1], line[2], line[3], line[4], line[5], line[6], line[7], line[8], line[9], line[10], 
                       line[11], line[12], line[13], line[14], line[15], line[16], line[17], line[18], line[19], line[20], 
                       line[21], line[22], line[23], line[24], line[25], line[26], line[27], line[28], line[29], line[30], 
                       line[31], line[32], line[33], line[34], line[35], line[36], line[37]))
conn.commit()
conn.close()
f.close()
