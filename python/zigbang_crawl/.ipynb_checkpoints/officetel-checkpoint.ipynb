# %%
import requests
import copy
import csv
import time
import json
import uuid
import pprint
import asyncio
from typing import List
from urllib import parse
from urllib.parse import quote
import inspect
import datetime

# %%
class magic_fstring_function:
    def __init__(self, payload):
        self.payload = payload
        self.cached = None
    def __str__(self):
        if self.cached is None:
            vars = inspect.currentframe().f_back.f_globals.copy()
            vars.update(inspect.currentframe().f_back.f_locals)
            self.cached = self.payload.format(**vars)
        return self.cached

# %%
uuid = str(uuid.uuid4())
item_list_api = "https://apis.zigbang.com/v2/items"
describe_list_api = item_list_api + '/list'
item_describe_api = "https://apis.zigbang.com/v3/items?item_ids={item_id}&detail=true"
item_view_url = "https://zigbang.com/home/officetel/items/{item_id}"

referer = "https://zigbang.com/home/officetel/subways/414/items"
        
headers = {
    'Host':'apis.zigbang.com',
    'Connection':'keep-alive',
    'Pragma':'no-cache',
    'Cache-Control':'no-cache',
    'Accept':'application/json, text/plain, */*',
    'Origin':'https://zigbang.com',
    'User-Agent':'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Mobile Safari/537.36',
    'DNT':'1',
    'Sec-Fetch-Site':'same-site',
    'Sec-Fetch-Mode':'cors',
    'Referer':'https://zigbang.com/home/officetel/subways/414/items',
    'Accept-Encoding':'gzip, deflate, br',
    'Accept-Language':'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
}

items = {}

# %%
def export_items(items):
    fieldnames = [
        'address1',
        'address2',
        'address3',
        'agent_address1',
        'agent_email',
        'agent_lat',
        'agent_lng',
        'agent_mobile',
        'agent_name',
        'agent_phone',
        'building_type',
        'deposit',
        'rent',
        'description',
        'elevator',
        'floor',
        'floor_all',
        'images',
        'local1',
        'local2',
        'local3',
        'manage_cost',
        'manage_cost_inc',
        'movein_date',
        'near_subways',
        'options',
        'parking',
        'pets_text',
        'random_location',
        'room_direction_text',
        'room_type',
        'sales_type',
        'service_type',
        'size',
        'size_m2',
        'title',
        'updated_at2',
        'user_intro',
        'user_name',
        'url'
    ]
    
    filtered_item = [] 

    for item in items:
        item = item['item']
        item_id = item['id']
        url = magic_fstring_function(item_view_url)
        item['url'] = str(url)
        new_item = {}
        for fieldname in fieldnames:
            new_item[fieldname] = item[fieldname]
        filtered_item.append(new_item)
    return filtered_item

# %%
def describe_room_list(items):
    item_ids = items
    max_idx = int(len(item_ids) / 30)
    if len(item_ids) % 30 != 0:
        max_idx += 1
    
    items = []
    headers['Accept'] = 'application/json'
    headers['Referer'] = 'https://zigbang.com/home/officetel/subways/37/items'
    
    for i in range(max_idx):
        start_idx = i * 30
        end_idx = min((i+1)*30, len(item_ids))
        sub_ids = item_ids[start_idx:end_idx-1]
        item_id = str(sub_ids).replace(' ', '').replace('\'','')
        api = magic_fstring_function(item_describe_api)
        g = api
        resp = requests.get(
            url=str(api),
            headers=headers,
            timeout=5,
        )
        resp.encoding = 'utf-8'
        result = resp.json()
        resp.close()
        items += result['items']
        time.sleep(1)
        
    return items

# %%
def get_room_list(
    items,
    domain: str = "zigbang",
    floor_in: str = "ground",
    geohash: str = "wyd",
    rent_gteq: int = 0,
):
    resp = requests.get(
        url=item_list_api,
        params={
            "domain": domain,
            "floor_in": floor_in,
            "geohash": geohash,
            "rent_gteq": rent_gteq,
        },
        headers=headers,
        timeout=5,
    )
    new_items = json.loads(resp.content.decode('utf-8'))
    resp.close()

    for section in new_items['sections']:
        for item in section['item_ids']:
            items.append(str(item))

    return items

# %%
items = []

# %%
geos_seoul = [
    'wydm',
    'wydq4',
    'wydq5',
    'wydjx',
    'wydjr',
    'wydjq'
] 

for geo in geos_seoul:
    items = get_room_list(items, geohash=geo)
    time.sleep(1)

# %%
len(items)
# Out:
# 9210

# %%
import random

random_items = random.sample(items, 5000)

# %%
result = describe_room_list(random_items)
len(result)
# Out:
# 4833

# %%
pp = pprint.PrettyPrinter(indent=2)
pp.pprint(result[0]['item'])
# Out:
# { '_floor': '5층',
#   'address1': '서울시 용산구 청파동3가',
#   'address2': '107-3',
#   'address3': None,
#   'agent_address1': '서울특별시 용산구 청파로43나길 2 1층',
#   'agent_comment': '',
#   'agent_email': 'yeesee4969@naver.com',
#   'agent_lat': 37.543679650415605,
#   'agent_lng': 126.969277245296,
#   'agent_local1': '서울시',
#   'agent_local2': '용산구',
#   'agent_mobile': '010-5017-0722',
#   'agent_name': '숙대참조은공인중개사사무소(이시현)',
#   'agent_no': 0,
#   'agent_phone': '02-717-4969',
#   'bjd_code': '',
#   'bonbun_code': '107',
#   'bubun_code': '3',
#   'building': None,
#   'building_type': '-',
#   'contract': '서울특별시',
#   'deposit': 33000,
#   'description': '- 신축 복층 전세입니다. \n'
#                  '\n'
#                  '- 화장실이 위아래층 한개씩 총 두개있어서 생활하시기 편리합니다. \n'
#                  '\n'
#                  '- 위아래층 모두 오픈형으로 확 트여있어 채광도 좋습니다.\n'
#                  '\n'
#                  '- 위치는 숙대입구역 도보 5분 거리로 평지에 위치하며 인근에 편의시설들이 많이있습니다.\n'
#                  '\n'
#                  '- 주차 가능합니다. \n'
#                  '\n'
#                  '- 전세자금 대출 가능합니다. \n'
#                  '\n'
#                  '- 옵션 : 천장형 에어컨, 세탁기, 인덕션, 빌트인냉장고 \n'
#                  '21.11.08에 직방에 등록된 매물입니다.',
#   'description_og': '- 신축 복층 전세입니다. \n'
#                     '\n'
#                     '- 화장실이 위아래층 한개씩 총 두개있어서 생활하시기 편리합니다. \n'
#                     '\n'
#                     '- 위아래층 모두 오픈형으로 확 트여있어 채광도 좋습니다.\n'
#                     '\n'
#                     '- 위치는 숙대입구역 도보 5분 거리로 평지에 위치하며 인근에 편의시설들이 많이있습니다.\n'
#                     '\n'
#                     '- 주차 가능합니다. \n'
#                     '\n'
#                     '- 전세자금 대출 가능합니다. \n'
#                     '\n'
#                     '- 옵션 : 천장형 에어컨, 세탁기, 인덕션, 빌트인냉장고 \n'
#                     '21.11.08에 직방에 등록된 매물입니다.',
#   'elevator': '있음',
#   'floor': '5층',
#   'floor_all': '5층',
#   'id': 29352801,
#   'images': [ { 'count': 1,
#                 'index': 0,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/1.jpg'},
#               { 'count': 2,
#                 'index': 1,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/2.jpg'},
#               { 'count': 3,
#                 'index': 2,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/3.jpg'},
#               { 'count': 4,
#                 'index': 3,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/4.jpg'},
#               { 'count': 5,
#                 'index': 4,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/5.jpg'},
#               { 'count': 6,
#                 'index': 5,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/6.jpg'},
#               { 'count': 7,
#                 'index': 6,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/7.jpg'},
#               { 'count': 8,
#                 'index': 7,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/8.jpg'},
#               { 'count': 9,
#                 'index': 8,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/9.jpg'},
#               { 'count': 10,
#                 'index': 9,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/10.jpg'},
#               { 'count': 11,
#                 'index': 10,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/11.jpg'},
#               { 'count': 12,
#                 'index': 11,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/12.jpg'},
#               { 'count': 13,
#                 'index': 12,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/13.jpg'}],
#   'images_thumbnail': '/items/29352801/1.jpg',
#   'is_deposit_only': True,
#   'is_direct': False,
#   'is_homepage': True,
#   'is_owner': False,
#   'is_premium': True,
#   'is_premium2': False,
#   'is_realestate': True,
#   'is_room': False,
#   'is_status_close': False,
#   'is_status_open': True,
#   'is_type_room': False,
#   'is_zzim': False,
#   'loan_text': '확인필요',
#   'local1': '서울시',
#   'local2': '용산구',
#   'local3': '청파동3가',
#   'manage_cost': '7만원',
#   'manage_cost_inc': '-',
#   'movein_date': '즉시 입주',
#   'near_subways': '숙대입구역(4호선), 남영역(1호선), 효창공원앞역(6호선)',
#   'options': '-',
#   'original_user_phone': '010-5017-0722',
#   'parking': '가능',
#   'pets_text': '확인필요',
#   'pnu': '1117011100101070003',
#   'premium_items': [],
#   'profile_url': 'http://ic.zigbang.com/vp/profile/13800678/2fdf82ea4d5ac1b1b82f0f4bed5a0fe7b029d940.jpg',
#   'random_location': '37.54398287799457,126.9687887715363',
#   'read_updated_at': '2001-01-01',
#   'rent': 0,
#   'room_direction_text': '동향',
#   'room_gubun_code': '04',
#   'room_type': '투룸',
#   'room_type_code': '04',
#   'sales_type': '전세',
#   'secret_memo': None,
#   'service_type': '빌라',
#   'size': 18,
#   'size_contract': 18.5,
#   'size_m2': 59.5,
#   'size_m2_contract': 61.16,
#   'status': '광고중',
#   'title': '신축★ 역세권 도보5분 평지에 위치한 복층전세 (대출가능)',
#   'updated_at': '어제',
#   'updated_at2': '2021-11-08',
#   'user_email': 'yeesee4969@naver.com',
#   'user_has_no_penalty': True,
#   'user_has_penalty': False,
#   'user_intro': '20년 경력과 부동산 전문 컨설턴트의 명예를 걸고 역동적인 "원스톱 서비스"로 숙대입구역,  서울역, '
#                 '효창공원, 삼각지, 공덕역을 비롯하여 후암동, 원효로의 원룸, 다세대, 다가구, 오피스텔, 아파트, 전세, '
#                 '월세, 매매, 단기 임대 매물을 취급하고 있습니다. \r\n'
#                 '전화 주시고 방문하시면 편하고 빠르게 고객님의 니즈에 맞춘 좋은 집을 "고객님을 내 가족처럼 생각하며" 최상의 '
#                 '매물을 보여드릴 것을 약속합니다. \r\n'
#                 '고객이 인정하는 No.1 부동산이 되도록 최선을 다하겠습니다. \r\n'
#                 '서울 용산구 청파로 43나길2, 참조은부동산',
#   'user_mobile': '0504-3128-6737',
#   'user_name': '대표공인중개사 이시현',
#   'user_no': 13800678,
#   'user_phone': '0504-3128-6737',
#   'view_count': '20'}

# %%
filtered_result = export_items(result)
len(filtered_result)
# Out:
# 4833

# %%
def get_string_image(item):
    image = ''
    
    for list in item:
        image += list['url'] + '?w=400&h=300&q=70&a=1,'
        
    return image[:-1]

# %%
def get_full_address(item):
    addr = item['address1']
    addr += ' '
    addr += item['address2'] or ''
    addr += ' '
    addr += item['address3'] or ''
    return addr

# %%
def get_location_lat(item):
    locationList = item['random_location'].split(',')

    lat = locationList[0][0:13]
    
    return lat

def get_location_lng(item):
    locationList = item['random_location'].split(',')

    lng = locationList[1][0:14]
    
    return lng

# %%
def get_agent_lat(item):
    agent_lat = str(item['agent_lat'])[0:13]
    
    return agent_lat

def get_agent_lng(item):
    agent_lng = str(item['agent_lng'])[0:14]
    
    return agent_lng

# %%
for item in filtered_result:
    item['address'] = get_full_address(item)
    item['lat'] = get_location_lat(item)
    item['lng'] = get_location_lng(item)
    item['image'] = get_string_image(item['images'])
    item['agent_lat'] = get_agent_lat(item)
    item['agent_lng'] = get_agent_lng(item)

# %%
pp = pprint.PrettyPrinter(indent=2)
pp.pprint(filtered_result[0])
# Out:
# { 'address': '서울시 용산구 청파동3가 107-3 ',
#   'address1': '서울시 용산구 청파동3가',
#   'address2': '107-3',
#   'address3': None,
#   'agent_address1': '서울특별시 용산구 청파로43나길 2 1층',
#   'agent_email': 'yeesee4969@naver.com',
#   'agent_lat': '37.5436796504',
#   'agent_lng': '126.9692772452',
#   'agent_mobile': '010-5017-0722',
#   'agent_name': '숙대참조은공인중개사사무소(이시현)',
#   'agent_phone': '02-717-4969',
#   'building_type': '-',
#   'deposit': 33000,
#   'description': '- 신축 복층 전세입니다. \n'
#                  '\n'
#                  '- 화장실이 위아래층 한개씩 총 두개있어서 생활하시기 편리합니다. \n'
#                  '\n'
#                  '- 위아래층 모두 오픈형으로 확 트여있어 채광도 좋습니다.\n'
#                  '\n'
#                  '- 위치는 숙대입구역 도보 5분 거리로 평지에 위치하며 인근에 편의시설들이 많이있습니다.\n'
#                  '\n'
#                  '- 주차 가능합니다. \n'
#                  '\n'
#                  '- 전세자금 대출 가능합니다. \n'
#                  '\n'
#                  '- 옵션 : 천장형 에어컨, 세탁기, 인덕션, 빌트인냉장고 \n'
#                  '21.11.08에 직방에 등록된 매물입니다.',
#   'elevator': '있음',
#   'floor': '5층',
#   'floor_all': '5층',
#   'image': 'https://ic.zigbang.com/ic/items/29352801/1.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29352801/2.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29352801/3.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29352801/4.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29352801/5.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29352801/6.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29352801/7.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29352801/8.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29352801/9.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29352801/10.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29352801/11.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29352801/12.jpg?w=400&h=300&q=70&a=1,https://ic.zigbang.com/ic/items/29352801/13.jpg?w=400&h=300&q=70&a=1',
#   'images': [ { 'count': 1,
#                 'index': 0,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/1.jpg'},
#               { 'count': 2,
#                 'index': 1,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/2.jpg'},
#               { 'count': 3,
#                 'index': 2,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/3.jpg'},
#               { 'count': 4,
#                 'index': 3,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/4.jpg'},
#               { 'count': 5,
#                 'index': 4,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/5.jpg'},
#               { 'count': 6,
#                 'index': 5,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/6.jpg'},
#               { 'count': 7,
#                 'index': 6,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/7.jpg'},
#               { 'count': 8,
#                 'index': 7,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/8.jpg'},
#               { 'count': 9,
#                 'index': 8,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/9.jpg'},
#               { 'count': 10,
#                 'index': 9,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/10.jpg'},
#               { 'count': 11,
#                 'index': 10,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/11.jpg'},
#               { 'count': 12,
#                 'index': 11,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/12.jpg'},
#               { 'count': 13,
#                 'index': 12,
#                 'url': 'https://ic.zigbang.com/ic/items/29352801/13.jpg'}],
#   'lat': '37.5439828779',
#   'lng': '126.9687887715',
#   'local1': '서울시',
#   'local2': '용산구',
#   'local3': '청파동3가',
#   'manage_cost': '7만원',
#   'manage_cost_inc': '-',
#   'movein_date': '즉시 입주',
#   'near_subways': '숙대입구역(4호선), 남영역(1호선), 효창공원앞역(6호선)',
#   'options': '-',
#   'parking': '가능',
#   'pets_text': '확인필요',
#   'random_location': '37.54398287799457,126.9687887715363',
#   'room_direction_text': '동향',
#   'room_type': '투룸',
#   'sales_type': '전세',
#   'service_type': '빌라',
#   'size': 18,
#   'size_m2': 59.5,
#   'title': '신축★ 역세권 도보5분 평지에 위치한 복층전세 (대출가능)',
#   'updated_at2': '2021-11-08',
#   'url': 'https://zigbang.com/home/officetel/items/29352801',
#   'user_intro': '20년 경력과 부동산 전문 컨설턴트의 명예를 걸고 역동적인 "원스톱 서비스"로 숙대입구역,  서울역, '
#                 '효창공원, 삼각지, 공덕역을 비롯하여 후암동, 원효로의 원룸, 다세대, 다가구, 오피스텔, 아파트, 전세, '
#                 '월세, 매매, 단기 임대 매물을 취급하고 있습니다. \r\n'
#                 '전화 주시고 방문하시면 편하고 빠르게 고객님의 니즈에 맞춘 좋은 집을 "고객님을 내 가족처럼 생각하며" 최상의 '
#                 '매물을 보여드릴 것을 약속합니다. \r\n'
#                 '고객이 인정하는 No.1 부동산이 되도록 최선을 다하겠습니다. \r\n'
#                 '서울 용산구 청파로 43나길2, 참조은부동산',
#   'user_name': '대표공인중개사 이시현'}

# %%
with open('officetel.csv', 'w', newline='', encoding='utf-8') as csvfile:
    fieldnames = [
        'address',
        'agent_address1',
        'agent_email',
        'agent_lat',
        'agent_lng',
        'agent_mobile',
        'agent_name',
        'agent_phone',
        'building_type',
        'deposit',
        'rent',
        'description',
        'elevator',
        'floor',
        'floor_all',
        'image',
        'lat',
        'lng',
        'local1',
        'local2',
        'local3',
        'manage_cost',
        'manage_cost_inc',
        'movein_date',
        'near_subways',
        'options',
        'parking',
        'pets_text',
        'room_direction_text',
        'room_type',
        'sales_type',
        'service_type',
        'size',
        'size_m2',
        'title',
        'updated_at2',
        'user_intro',
        'user_name',
        'url'
    ]
    writer = csv.DictWriter(csvfile, extrasaction='ignore', fieldnames=fieldnames)
    writer.writeheader()
    for item in filtered_result:
        writer.writerow(item)

# %%
import pymysql
import csv
conn = pymysql.connect(host='localhost', user='khweb', password='khWeb@123', db='mybang_db', charset='utf8mb4')
curs = conn.cursor()

sql = """insert into officetel (address, agent_address, agent_email, agent_lat, agent_lng,
                                agent_mobile, agent_name, agent_phone, building_type, deposit, rent,
                                description, elevator, floor, floor_all, image,
                                lat, lng, local1, local2, local3,
                                manage_cost, manage_cost_inc, movein_date, near_subways, options,
                                parking, pets, room_direction, room_type, sales_type,
                                service_type, size, size_m2, title, updated_at,
                                user_intro, user_name, url)
                                values (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,
                                        # %s,%s,%s,%s,%s,%s,%s,%s,%s,%s,
                                        # %s,%s,%s,%s,%s,%s,%s,%s,%s,%s,
                                        # %s,%s,%s,%s,%s,%s,%s,%s)"""

f = open('officetel.csv', 'r', encoding='utf-8')
rd = csv.reader(f)

next(rd)

for line in rd:
    curs.execute(sql, (line[0], line[1], line[2], line[3], line[4], line[5], line[6], line[7], line[8], line[9], line[10], 
                       line[11], line[12], line[13], line[14], line[15], line[16], line[17], line[18], line[19], line[20], 
                       line[21], line[22], line[23], line[24], line[25], line[26], line[27], line[28], line[29], line[30], 
                       line[31], line[32], line[33], line[34], line[35], line[36], line[37], line[38]))
conn.commit()
conn.close()
f.close()
